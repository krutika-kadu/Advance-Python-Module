# %% [markdown]
# ## API

# %% [markdown]
# #### Retrive the most popular movies from IMDB Website

# %%
# %pip install python-dotenv requests
# Out:
# Requirement already satisfied: python-dotenv in e:\krutika\advance python\repository\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: requests in e:\krutika\advance python\repository\venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\krutika\advance python\repository\venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in e:\krutika\advance python\repository\venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\krutika\advance python\repository\venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\krutika\advance python\repository\venv\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
api_key = os.getenv("API_KEY")

# %%
import requests

url = "https://imdb232.p.rapidapi.com/api/title/get-most-popular"

querystring = {"limit":"20","topMeterTitlesType":"ALL"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "imdb232.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()

# %%
data
# Out:
# {'data': {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#       'id': 'tt6208148',
#       'titleText': {'text': 'Snow White', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Snow White', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 21,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2593229058',
#        'url': 'https://m.media-amazon.com/images/M/MV5BY2UwOGUxMzEtMzEyZi00NjEwLTkxOTMtYTljOWEzYjYyMWNjXkEyXkFqcGc@._V1_.jpg',
#        'height': 2500,
#        'width': 1688},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13406094',
#       'titleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The White Lotus',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm437293314',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmM1MGM0MDQtZTAzNy00ZGJkLWI4MDUtNjBmMzdhYjhlM2QwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 810},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt3566834',
#       'titleText': {'text': 'A Minecraft Movie', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'A Minecraft Movie',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 4,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3887434498',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYzFjMzNjOTktNDBlNy00YWZhLWExYTctZDcxNDA4OWVhOTJjXkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31806037',
#       'titleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 13,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1814727170',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNGY1YjBiNzMtYWZhNC00OWViLWE0MzItNjc4YzczOGNiM2I0XkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31510819',
#       'titleText': {'text': 'MobLand', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'MobLand', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 30,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3442052866',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjQzZWVkMDQtZTgyZC00ZjVlLThlMTktNDBjNDU1Y2JhNDhkXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'UP', 'difference': 56}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt11280740',
#       'titleText': {'text': 'Severance', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Severance', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 2,
#        'day': 18,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1676647938',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZDI5YzJhODQtMzQyNy00YWNmLWIxMjUtNDBjNjA5YWRjMzExXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt18923754',
#       'titleText': {'text': 'Daredevil: Born Again', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Daredevil: Born Again',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 4,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1760660226',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDRiNTBlY2EtZmRiZC00Mzc4LTljZDctNWQ5ZGY2NjUwNjE4XkEyXkFqcGc@._V1_.jpg',
#        'height': 1599,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt8740614',
#       'titleText': {'text': 'The Residence', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Residence', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 20,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2885784834',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNmJlOWFiNGEtZGYyMy00ZWY5LWJlMjMtYjgzZTViNDI3NzUxXkEyXkFqcGc@._V1_.jpg',
#        'height': 12000,
#        'width': 8100},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt18335752',
#       'titleText': {'text': '1923', 'isOriginalTitle': False},
#       'originalTitleText': {'text': '1923: A Yellowstone Origin Story',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 12,
#        'day': 18,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2131792898',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MGViZTItMmI5NS00MzMwLWFkNjctOGFlNWVmNDM0N2QyXkEyXkFqcGc@._V1_.jpg',
#        'height': 4000,
#        'width': 2700},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31938062',
#       'titleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 1,
#        'day': 9,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2334957058',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MDliMGEtMDQxNi00OTk1LTg1NWMtZDM2NmEwZDA1ZDk2XkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 810},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt9288030',
#       'titleText': {'text': 'Reacher', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Reacher', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 2,
#        'day': 4,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1559797250',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMzdjYWZlMDQtYzdhNi00NmRlLTg2NzUtMTI3MWFhZDliNjBiXkEyXkFqcGc@._V1_.jpg',
#        'height': 1920,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 9,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt2172954',
#       'titleText': {'text': 'The Life List', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Life List', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 28,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2935720450',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMjNhNzUyMTQtYTFiZS00NzM2LWI3YTgtZmI1ZTA1MDUzMzBhXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'UP', 'difference': 39}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt23649128',
#       'titleText': {'text': 'The Studio', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Studio', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 26,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm935172866',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDQxMWI5OTMtNGRkMC00NTVlLWI5ZjAtZmFiMjMwM2M0N2E0XkEyXkFqcGc@._V1_.jpg',
#        'height': 755,
#        'width': 604},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 10,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt28256288',
#       'titleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 3,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1499500034',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZjczOGY5MzEtYWJiNS00ZDQyLThhNzAtZTVhMTkxOWI3MjczXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 11,
#        'rankChange': {'changeDirection': 'UP', 'difference': 600}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt9150192',
#       'titleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 28,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3791164162',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYmQxZGIxNTYtYTQwMy00ODdkLWI0MmQtM2E0ZmIyNmYzMGMzXkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt30988739',
#       'titleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 14,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2339149314',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNzA1OWU4NDMtMDUxMC00NWI4LWJhYjUtYWQ0OGQ5MTc2NDRjXkEyXkFqcGc@._V1_.jpg',
#        'height': 12000,
#        'width': 8100},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt7462410',
#       'titleText': {'text': 'The Wheel of Time', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Wheel of Time',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 11,
#        'day': 19,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4100690946',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNmQ5Y2U2MWYtZDcyMi00YTk5LWEyYjItNTI3ODg4MTdlMjYwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 960},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 12,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt6741278',
#       'titleText': {'text': 'Invincible', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Invincible', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 26,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1526242818',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZjE4ZDU4ZjMtZjliYS00M2ZmLThkNTItN2U3MmJjOGU0NmIxXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 13,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 5}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt11041332',
#       'titleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 11,
#        'day': 14,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm636520962',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDAwMDNiNDAtZjM0Yi00OTEyLWFkMGUtMzIxOGU0NWYzYmM4XkEyXkFqcGc@._V1_.jpg',
#        'height': 4000,
#        'width': 2700},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 14,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt32641461',
#       'titleText': {'text': 'Mid-Century Modern', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Mid-Century Modern',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 28,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1986103298',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYmQ2MDE4M2YtNTBiYi00YWYzLTk3YWMtOTk1NWZkYWQwZWExXkEyXkFqcGc@._V1_.jpg',
#        'height': 12000,
#        'width': 8100},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 15,
#        'rankChange': {'changeDirection': 'UP', 'difference': 16}}}}]}}}

# %%
type(data)
# Out:
# dict

# %%
empdata ={
    "name":["sindhura","thaman"]
}

# %%
empdata["name"]
# Out:
# ['sindhura', 'thaman']

# %%
#empdata["id"]

# %%
empdata.get("name")
# Out:
# ['sindhura', 'thaman']

# %%
empdata.get("id","no data")
# Out:
# 'no data'

# %%
empdata.get("id",[])
# Out:
# []

# %%
data
# Out:
# {'data': {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#       'id': 'tt6208148',
#       'titleText': {'text': 'Snow White', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Snow White', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 21,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2593229058',
#        'url': 'https://m.media-amazon.com/images/M/MV5BY2UwOGUxMzEtMzEyZi00NjEwLTkxOTMtYTljOWEzYjYyMWNjXkEyXkFqcGc@._V1_.jpg',
#        'height': 2500,
#        'width': 1688},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt13406094',
#       'titleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The White Lotus',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 7,
#        'day': 11,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm437293314',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZmM1MGM0MDQtZTAzNy00ZGJkLWI4MDUtNjBmMzdhYjhlM2QwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 810},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 1,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt3566834',
#       'titleText': {'text': 'A Minecraft Movie', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'A Minecraft Movie',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 4,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3887434498',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYzFjMzNjOTktNDBlNy00YWZhLWExYTctZDcxNDA4OWVhOTJjXkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31806037',
#       'titleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 13,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1814727170',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNGY1YjBiNzMtYWZhNC00OWViLWE0MzItNjc4YzczOGNiM2I0XkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 2,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31510819',
#       'titleText': {'text': 'MobLand', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'MobLand', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 30,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3442052866',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNjQzZWVkMDQtZTgyZC00ZjVlLThlMTktNDBjNDU1Y2JhNDhkXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'UP', 'difference': 56}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt11280740',
#       'titleText': {'text': 'Severance', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Severance', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 2,
#        'day': 18,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1676647938',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZDI5YzJhODQtMzQyNy00YWNmLWIxMjUtNDBjNjA5YWRjMzExXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt18923754',
#       'titleText': {'text': 'Daredevil: Born Again', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Daredevil: Born Again',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 4,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1760660226',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDRiNTBlY2EtZmRiZC00Mzc4LTljZDctNWQ5ZGY2NjUwNjE4XkEyXkFqcGc@._V1_.jpg',
#        'height': 1599,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt8740614',
#       'titleText': {'text': 'The Residence', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Residence', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 20,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvMiniSeries',
#        'text': 'TV Mini Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2885784834',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNmJlOWFiNGEtZGYyMy00ZWY5LWJlMjMtYjgzZTViNDI3NzUxXkEyXkFqcGc@._V1_.jpg',
#        'height': 12000,
#        'width': 8100},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 6,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt18335752',
#       'titleText': {'text': '1923', 'isOriginalTitle': False},
#       'originalTitleText': {'text': '1923: A Yellowstone Origin Story',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': 2025},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 12,
#        'day': 18,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2131792898',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MGViZTItMmI5NS00MzMwLWFkNjctOGFlNWVmNDM0N2QyXkEyXkFqcGc@._V1_.jpg',
#        'height': 4000,
#        'width': 2700},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 7,
#        'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt31938062',
#       'titleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 1,
#        'day': 9,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2334957058',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MDliMGEtMDQxNi00OTk1LTg1NWMtZDM2NmEwZDA1ZDk2XkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 810},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 8,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt9288030',
#       'titleText': {'text': 'Reacher', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Reacher', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2022,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 2,
#        'day': 4,
#        'year': 2022,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1559797250',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMzdjYWZlMDQtYzdhNi00NmRlLTg2NzUtMTI3MWFhZDliNjBiXkEyXkFqcGc@._V1_.jpg',
#        'height': 1920,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 9,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt2172954',
#       'titleText': {'text': 'The Life List', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Life List', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 28,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2935720450',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMjNhNzUyMTQtYTFiZS00NzM2LWI3YTgtZmI1ZTA1MDUzMzBhXkEyXkFqcGc@._V1_.jpg',
#        'height': 2222,
#        'width': 1500},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 3,
#        'rankChange': {'changeDirection': 'UP', 'difference': 39}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt23649128',
#       'titleText': {'text': 'The Studio', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Studio', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 26,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm935172866',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDQxMWI5OTMtNGRkMC00NTVlLWI5ZjAtZmFiMjMwM2M0N2E0XkEyXkFqcGc@._V1_.jpg',
#        'height': 755,
#        'width': 604},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 10,
#        'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt28256288',
#       'titleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 4,
#        'day': 3,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1499500034',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZjczOGY5MzEtYWJiNS00ZDQyLThhNzAtZTVhMTkxOWI3MjczXkEyXkFqcGc@._V1_.jpg',
#        'height': 1350,
#        'width': 1080},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 11,
#        'rankChange': {'changeDirection': 'UP', 'difference': 600}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt9150192',
#       'titleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 28,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm3791164162',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYmQxZGIxNTYtYTQwMy00ODdkLWI0MmQtM2E0ZmIyNmYzMGMzXkEyXkFqcGc@._V1_.jpg',
#        'height': 4096,
#        'width': 2764},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 4,
#        'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt30988739',
#       'titleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 14,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'movie',
#        'text': 'Movie',
#        'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#        'canHaveEpisodes': False,
#        'isEpisode': False,
#        'isSeries': False,
#        'displayableProperty': {'value': {'plainText': ''}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm2339149314',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNzA1OWU4NDMtMDUxMC00NWI4LWJhYjUtYWQ0OGQ5MTc2NDRjXkEyXkFqcGc@._V1_.jpg',
#        'height': 12000,
#        'width': 8100},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 5,
#        'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt7462410',
#       'titleText': {'text': 'The Wheel of Time', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'The Wheel of Time',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 11,
#        'day': 19,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm4100690946',
#        'url': 'https://m.media-amazon.com/images/M/MV5BNmQ5Y2U2MWYtZDcyMi00YTk5LWEyYjItNTI3ODg4MTdlMjYwXkEyXkFqcGc@._V1_.jpg',
#        'height': 1200,
#        'width': 960},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 12,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt6741278',
#       'titleText': {'text': 'Invincible', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Invincible', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 26,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1526242818',
#        'url': 'https://m.media-amazon.com/images/M/MV5BZjE4ZDU4ZjMtZjliYS00M2ZmLThkNTItN2U3MmJjOGU0NmIxXkEyXkFqcGc@._V1_.jpg',
#        'height': 3000,
#        'width': 2000},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 13,
#        'rankChange': {'changeDirection': 'DOWN', 'difference': 5}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt11041332',
#       'titleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2021,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 11,
#        'day': 14,
#        'year': 2021,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm636520962',
#        'url': 'https://m.media-amazon.com/images/M/MV5BMDAwMDNiNDAtZjM0Yi00OTEyLWFkMGUtMzIxOGU0NWYzYmM4XkEyXkFqcGc@._V1_.jpg',
#        'height': 4000,
#        'width': 2700},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 14,
#        'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#     {'node': {'__typename': 'Title',
#       'id': 'tt32641461',
#       'titleText': {'text': 'Mid-Century Modern', 'isOriginalTitle': True},
#       'originalTitleText': {'text': 'Mid-Century Modern',
#        'isOriginalTitle': True},
#       'releaseYear': {'__typename': 'YearRange',
#        'year': 2025,
#        'endYear': None},
#       'releaseDate': {'__typename': 'ReleaseDate',
#        'month': 3,
#        'day': 28,
#        'year': 2025,
#        'country': {'id': 'US'},
#        'restriction': None,
#        'attributes': [{'id': 'internet', 'text': 'internet'}],
#        'displayableProperty': {'qualifiersInMarkdownList': None}},
#       'titleType': {'__typename': 'TitleType',
#        'id': 'tvSeries',
#        'text': 'TV Series',
#        'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#        'canHaveEpisodes': True,
#        'isEpisode': False,
#        'isSeries': True,
#        'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#       'primaryImage': {'__typename': 'Image',
#        'id': 'rm1986103298',
#        'url': 'https://m.media-amazon.com/images/M/MV5BYmQ2MDE4M2YtNTBiYi00YWYzLTk3YWMtOTk1NWZkYWQwZWExXkEyXkFqcGc@._V1_.jpg',
#        'height': 12000,
#        'width': 8100},
#       'meterRanking': {'__typename': 'TitleMeterRanking',
#        'currentRank': 15,
#        'rankChange': {'changeDirection': 'UP', 'difference': 16}}}}]}}}

# %%
data.get("data",{})
# Out:
# {'topMeterTitles': {'edges': [{'node': {'__typename': 'Title',
#      'id': 'tt6208148',
#      'titleText': {'text': 'Snow White', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Snow White', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 21,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2593229058',
#       'url': 'https://m.media-amazon.com/images/M/MV5BY2UwOGUxMzEtMzEyZi00NjEwLTkxOTMtYTljOWEzYjYyMWNjXkEyXkFqcGc@._V1_.jpg',
#       'height': 2500,
#       'width': 1688},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 1,
#       'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt13406094',
#      'titleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 7,
#       'day': 11,
#       'year': 2021,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm437293314',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZmM1MGM0MDQtZTAzNy00ZGJkLWI4MDUtNjBmMzdhYjhlM2QwXkEyXkFqcGc@._V1_.jpg',
#       'height': 1200,
#       'width': 810},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 1,
#       'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt3566834',
#      'titleText': {'text': 'A Minecraft Movie', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'A Minecraft Movie',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 4,
#       'day': 4,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3887434498',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYzFjMzNjOTktNDBlNy00YWZhLWExYTctZDcxNDA4OWVhOTJjXkEyXkFqcGc@._V1_.jpg',
#       'height': 4096,
#       'width': 2764},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 2,
#       'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31806037',
#      'titleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 13,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvMiniSeries',
#       'text': 'TV Mini Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1814727170',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNGY1YjBiNzMtYWZhNC00OWViLWE0MzItNjc4YzczOGNiM2I0XkEyXkFqcGc@._V1_.jpg',
#       'height': 2222,
#       'width': 1500},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 2,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31510819',
#      'titleText': {'text': 'MobLand', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'MobLand', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 30,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3442052866',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNjQzZWVkMDQtZTgyZC00ZjVlLThlMTktNDBjNDU1Y2JhNDhkXkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2000},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 3,
#       'rankChange': {'changeDirection': 'UP', 'difference': 56}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt11280740',
#      'titleText': {'text': 'Severance', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Severance', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 2,
#       'day': 18,
#       'year': 2022,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1676647938',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZDI5YzJhODQtMzQyNy00YWNmLWIxMjUtNDBjNjA5YWRjMzExXkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2000},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 4,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt18923754',
#      'titleText': {'text': 'Daredevil: Born Again', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Daredevil: Born Again',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 4,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1760660226',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMDRiNTBlY2EtZmRiZC00Mzc4LTljZDctNWQ5ZGY2NjUwNjE4XkEyXkFqcGc@._V1_.jpg',
#       'height': 1599,
#       'width': 1080},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 5,
#       'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt8740614',
#      'titleText': {'text': 'The Residence', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Residence', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 20,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvMiniSeries',
#       'text': 'TV Mini Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2885784834',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNmJlOWFiNGEtZGYyMy00ZWY5LWJlMjMtYjgzZTViNDI3NzUxXkEyXkFqcGc@._V1_.jpg',
#       'height': 12000,
#       'width': 8100},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 6,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt18335752',
#      'titleText': {'text': '1923', 'isOriginalTitle': False},
#      'originalTitleText': {'text': '1923: A Yellowstone Origin Story',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': 2025},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 12,
#       'day': 18,
#       'year': 2022,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2131792898',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MGViZTItMmI5NS00MzMwLWFkNjctOGFlNWVmNDM0N2QyXkEyXkFqcGc@._V1_.jpg',
#       'height': 4000,
#       'width': 2700},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 7,
#       'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt31938062',
#      'titleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 1,
#       'day': 9,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2334957058',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MDliMGEtMDQxNi00OTk1LTg1NWMtZDM2NmEwZDA1ZDk2XkEyXkFqcGc@._V1_.jpg',
#       'height': 1200,
#       'width': 810},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 8,
#       'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt9288030',
#      'titleText': {'text': 'Reacher', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Reacher', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 2,
#       'day': 4,
#       'year': 2022,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1559797250',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMzdjYWZlMDQtYzdhNi00NmRlLTg2NzUtMTI3MWFhZDliNjBiXkEyXkFqcGc@._V1_.jpg',
#       'height': 1920,
#       'width': 1080},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 9,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt2172954',
#      'titleText': {'text': 'The Life List', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Life List', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 28,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2935720450',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMjNhNzUyMTQtYTFiZS00NzM2LWI3YTgtZmI1ZTA1MDUzMzBhXkEyXkFqcGc@._V1_.jpg',
#       'height': 2222,
#       'width': 1500},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 3,
#       'rankChange': {'changeDirection': 'UP', 'difference': 39}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt23649128',
#      'titleText': {'text': 'The Studio', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Studio', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 26,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm935172866',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMDQxMWI5OTMtNGRkMC00NTVlLWI5ZjAtZmFiMjMwM2M0N2E0XkEyXkFqcGc@._V1_.jpg',
#       'height': 755,
#       'width': 604},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 10,
#       'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt28256288',
#      'titleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 4,
#       'day': 3,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1499500034',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZjczOGY5MzEtYWJiNS00ZDQyLThhNzAtZTVhMTkxOWI3MjczXkEyXkFqcGc@._V1_.jpg',
#       'height': 1350,
#       'width': 1080},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 11,
#       'rankChange': {'changeDirection': 'UP', 'difference': 600}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt9150192',
#      'titleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 28,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm3791164162',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYmQxZGIxNTYtYTQwMy00ODdkLWI0MmQtM2E0ZmIyNmYzMGMzXkEyXkFqcGc@._V1_.jpg',
#       'height': 4096,
#       'width': 2764},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 4,
#       'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt30988739',
#      'titleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 14,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'movie',
#       'text': 'Movie',
#       'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#       'canHaveEpisodes': False,
#       'isEpisode': False,
#       'isSeries': False,
#       'displayableProperty': {'value': {'plainText': ''}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm2339149314',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNzA1OWU4NDMtMDUxMC00NWI4LWJhYjUtYWQ0OGQ5MTc2NDRjXkEyXkFqcGc@._V1_.jpg',
#       'height': 12000,
#       'width': 8100},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 5,
#       'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt7462410',
#      'titleText': {'text': 'The Wheel of Time', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'The Wheel of Time',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 11,
#       'day': 19,
#       'year': 2021,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm4100690946',
#       'url': 'https://m.media-amazon.com/images/M/MV5BNmQ5Y2U2MWYtZDcyMi00YTk5LWEyYjItNTI3ODg4MTdlMjYwXkEyXkFqcGc@._V1_.jpg',
#       'height': 1200,
#       'width': 960},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 12,
#       'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt6741278',
#      'titleText': {'text': 'Invincible', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Invincible', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 26,
#       'year': 2021,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1526242818',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZjE4ZDU4ZjMtZjliYS00M2ZmLThkNTItN2U3MmJjOGU0NmIxXkEyXkFqcGc@._V1_.jpg',
#       'height': 3000,
#       'width': 2000},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 13,
#       'rankChange': {'changeDirection': 'DOWN', 'difference': 5}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt11041332',
#      'titleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 11,
#       'day': 14,
#       'year': 2021,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm636520962',
#       'url': 'https://m.media-amazon.com/images/M/MV5BMDAwMDNiNDAtZjM0Yi00OTEyLWFkMGUtMzIxOGU0NWYzYmM4XkEyXkFqcGc@._V1_.jpg',
#       'height': 4000,
#       'width': 2700},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 14,
#       'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#    {'node': {'__typename': 'Title',
#      'id': 'tt32641461',
#      'titleText': {'text': 'Mid-Century Modern', 'isOriginalTitle': True},
#      'originalTitleText': {'text': 'Mid-Century Modern',
#       'isOriginalTitle': True},
#      'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#      'releaseDate': {'__typename': 'ReleaseDate',
#       'month': 3,
#       'day': 28,
#       'year': 2025,
#       'country': {'id': 'US'},
#       'restriction': None,
#       'attributes': [{'id': 'internet', 'text': 'internet'}],
#       'displayableProperty': {'qualifiersInMarkdownList': None}},
#      'titleType': {'__typename': 'TitleType',
#       'id': 'tvSeries',
#       'text': 'TV Series',
#       'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#       'canHaveEpisodes': True,
#       'isEpisode': False,
#       'isSeries': True,
#       'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#      'primaryImage': {'__typename': 'Image',
#       'id': 'rm1986103298',
#       'url': 'https://m.media-amazon.com/images/M/MV5BYmQ2MDE4M2YtNTBiYi00YWYzLTk3YWMtOTk1NWZkYWQwZWExXkEyXkFqcGc@._V1_.jpg',
#       'height': 12000,
#       'width': 8100},
#      'meterRanking': {'__typename': 'TitleMeterRanking',
#       'currentRank': 15,
#       'rankChange': {'changeDirection': 'UP', 'difference': 16}}}}]}}

# %%
data.get("data").get("topMeterTitles")
# Out:
# {'edges': [{'node': {'__typename': 'Title',
#     'id': 'tt6208148',
#     'titleText': {'text': 'Snow White', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Snow White', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 21,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2593229058',
#      'url': 'https://m.media-amazon.com/images/M/MV5BY2UwOGUxMzEtMzEyZi00NjEwLTkxOTMtYTljOWEzYjYyMWNjXkEyXkFqcGc@._V1_.jpg',
#      'height': 2500,
#      'width': 1688},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 1,
#      'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt13406094',
#     'titleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 7,
#      'day': 11,
#      'year': 2021,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm437293314',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZmM1MGM0MDQtZTAzNy00ZGJkLWI4MDUtNjBmMzdhYjhlM2QwXkEyXkFqcGc@._V1_.jpg',
#      'height': 1200,
#      'width': 810},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 1,
#      'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt3566834',
#     'titleText': {'text': 'A Minecraft Movie', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'A Minecraft Movie',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 4,
#      'day': 4,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3887434498',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYzFjMzNjOTktNDBlNy00YWZhLWExYTctZDcxNDA4OWVhOTJjXkEyXkFqcGc@._V1_.jpg',
#      'height': 4096,
#      'width': 2764},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 2,
#      'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31806037',
#     'titleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 13,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvMiniSeries',
#      'text': 'TV Mini Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1814727170',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNGY1YjBiNzMtYWZhNC00OWViLWE0MzItNjc4YzczOGNiM2I0XkEyXkFqcGc@._V1_.jpg',
#      'height': 2222,
#      'width': 1500},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 2,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31510819',
#     'titleText': {'text': 'MobLand', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'MobLand', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 30,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3442052866',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNjQzZWVkMDQtZTgyZC00ZjVlLThlMTktNDBjNDU1Y2JhNDhkXkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2000},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 3,
#      'rankChange': {'changeDirection': 'UP', 'difference': 56}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt11280740',
#     'titleText': {'text': 'Severance', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Severance', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 2,
#      'day': 18,
#      'year': 2022,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1676647938',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZDI5YzJhODQtMzQyNy00YWNmLWIxMjUtNDBjNjA5YWRjMzExXkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2000},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 4,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt18923754',
#     'titleText': {'text': 'Daredevil: Born Again', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Daredevil: Born Again',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 4,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1760660226',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDRiNTBlY2EtZmRiZC00Mzc4LTljZDctNWQ5ZGY2NjUwNjE4XkEyXkFqcGc@._V1_.jpg',
#      'height': 1599,
#      'width': 1080},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 5,
#      'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt8740614',
#     'titleText': {'text': 'The Residence', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Residence', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 20,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvMiniSeries',
#      'text': 'TV Mini Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2885784834',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmJlOWFiNGEtZGYyMy00ZWY5LWJlMjMtYjgzZTViNDI3NzUxXkEyXkFqcGc@._V1_.jpg',
#      'height': 12000,
#      'width': 8100},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 6,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt18335752',
#     'titleText': {'text': '1923', 'isOriginalTitle': False},
#     'originalTitleText': {'text': '1923: A Yellowstone Origin Story',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': 2025},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 12,
#      'day': 18,
#      'year': 2022,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2131792898',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MGViZTItMmI5NS00MzMwLWFkNjctOGFlNWVmNDM0N2QyXkEyXkFqcGc@._V1_.jpg',
#      'height': 4000,
#      'width': 2700},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 7,
#      'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt31938062',
#     'titleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 1,
#      'day': 9,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2334957058',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MDliMGEtMDQxNi00OTk1LTg1NWMtZDM2NmEwZDA1ZDk2XkEyXkFqcGc@._V1_.jpg',
#      'height': 1200,
#      'width': 810},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 8,
#      'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt9288030',
#     'titleText': {'text': 'Reacher', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Reacher', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 2,
#      'day': 4,
#      'year': 2022,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1559797250',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMzdjYWZlMDQtYzdhNi00NmRlLTg2NzUtMTI3MWFhZDliNjBiXkEyXkFqcGc@._V1_.jpg',
#      'height': 1920,
#      'width': 1080},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 9,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt2172954',
#     'titleText': {'text': 'The Life List', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Life List', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 28,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2935720450',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMjNhNzUyMTQtYTFiZS00NzM2LWI3YTgtZmI1ZTA1MDUzMzBhXkEyXkFqcGc@._V1_.jpg',
#      'height': 2222,
#      'width': 1500},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 3,
#      'rankChange': {'changeDirection': 'UP', 'difference': 39}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt23649128',
#     'titleText': {'text': 'The Studio', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Studio', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 26,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm935172866',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDQxMWI5OTMtNGRkMC00NTVlLWI5ZjAtZmFiMjMwM2M0N2E0XkEyXkFqcGc@._V1_.jpg',
#      'height': 755,
#      'width': 604},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 10,
#      'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt28256288',
#     'titleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 4,
#      'day': 3,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1499500034',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjczOGY5MzEtYWJiNS00ZDQyLThhNzAtZTVhMTkxOWI3MjczXkEyXkFqcGc@._V1_.jpg',
#      'height': 1350,
#      'width': 1080},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 11,
#      'rankChange': {'changeDirection': 'UP', 'difference': 600}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt9150192',
#     'titleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 28,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm3791164162',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmQxZGIxNTYtYTQwMy00ODdkLWI0MmQtM2E0ZmIyNmYzMGMzXkEyXkFqcGc@._V1_.jpg',
#      'height': 4096,
#      'width': 2764},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 4,
#      'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt30988739',
#     'titleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 14,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'movie',
#      'text': 'Movie',
#      'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#      'canHaveEpisodes': False,
#      'isEpisode': False,
#      'isSeries': False,
#      'displayableProperty': {'value': {'plainText': ''}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm2339149314',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNzA1OWU4NDMtMDUxMC00NWI4LWJhYjUtYWQ0OGQ5MTc2NDRjXkEyXkFqcGc@._V1_.jpg',
#      'height': 12000,
#      'width': 8100},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 5,
#      'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt7462410',
#     'titleText': {'text': 'The Wheel of Time', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'The Wheel of Time',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 11,
#      'day': 19,
#      'year': 2021,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm4100690946',
#      'url': 'https://m.media-amazon.com/images/M/MV5BNmQ5Y2U2MWYtZDcyMi00YTk5LWEyYjItNTI3ODg4MTdlMjYwXkEyXkFqcGc@._V1_.jpg',
#      'height': 1200,
#      'width': 960},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 12,
#      'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt6741278',
#     'titleText': {'text': 'Invincible', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Invincible', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 26,
#      'year': 2021,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1526242818',
#      'url': 'https://m.media-amazon.com/images/M/MV5BZjE4ZDU4ZjMtZjliYS00M2ZmLThkNTItN2U3MmJjOGU0NmIxXkEyXkFqcGc@._V1_.jpg',
#      'height': 3000,
#      'width': 2000},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 13,
#      'rankChange': {'changeDirection': 'DOWN', 'difference': 5}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt11041332',
#     'titleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 11,
#      'day': 14,
#      'year': 2021,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm636520962',
#      'url': 'https://m.media-amazon.com/images/M/MV5BMDAwMDNiNDAtZjM0Yi00OTEyLWFkMGUtMzIxOGU0NWYzYmM4XkEyXkFqcGc@._V1_.jpg',
#      'height': 4000,
#      'width': 2700},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 14,
#      'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#   {'node': {'__typename': 'Title',
#     'id': 'tt32641461',
#     'titleText': {'text': 'Mid-Century Modern', 'isOriginalTitle': True},
#     'originalTitleText': {'text': 'Mid-Century Modern',
#      'isOriginalTitle': True},
#     'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#     'releaseDate': {'__typename': 'ReleaseDate',
#      'month': 3,
#      'day': 28,
#      'year': 2025,
#      'country': {'id': 'US'},
#      'restriction': None,
#      'attributes': [{'id': 'internet', 'text': 'internet'}],
#      'displayableProperty': {'qualifiersInMarkdownList': None}},
#     'titleType': {'__typename': 'TitleType',
#      'id': 'tvSeries',
#      'text': 'TV Series',
#      'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#      'canHaveEpisodes': True,
#      'isEpisode': False,
#      'isSeries': True,
#      'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#     'primaryImage': {'__typename': 'Image',
#      'id': 'rm1986103298',
#      'url': 'https://m.media-amazon.com/images/M/MV5BYmQ2MDE4M2YtNTBiYi00YWYzLTk3YWMtOTk1NWZkYWQwZWExXkEyXkFqcGc@._V1_.jpg',
#      'height': 12000,
#      'width': 8100},
#     'meterRanking': {'__typename': 'TitleMeterRanking',
#      'currentRank': 15,
#      'rankChange': {'changeDirection': 'UP', 'difference': 16}}}}]}

# %%
data.get("data").get("topMeterTitles").get("edges")
# Out:
# [{'node': {'__typename': 'Title',
#    'id': 'tt6208148',
#    'titleText': {'text': 'Snow White', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Snow White', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 21,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2593229058',
#     'url': 'https://m.media-amazon.com/images/M/MV5BY2UwOGUxMzEtMzEyZi00NjEwLTkxOTMtYTljOWEzYjYyMWNjXkEyXkFqcGc@._V1_.jpg',
#     'height': 2500,
#     'width': 1688},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 1,
#     'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt13406094',
#    'titleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The White Lotus', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 7,
#     'day': 11,
#     'year': 2021,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm437293314',
#     'url': 'https://m.media-amazon.com/images/M/MV5BZmM1MGM0MDQtZTAzNy00ZGJkLWI4MDUtNjBmMzdhYjhlM2QwXkEyXkFqcGc@._V1_.jpg',
#     'height': 1200,
#     'width': 810},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 1,
#     'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt3566834',
#    'titleText': {'text': 'A Minecraft Movie', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'A Minecraft Movie', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 4,
#     'day': 4,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3887434498',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYzFjMzNjOTktNDBlNy00YWZhLWExYTctZDcxNDA4OWVhOTJjXkEyXkFqcGc@._V1_.jpg',
#     'height': 4096,
#     'width': 2764},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 2,
#     'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31806037',
#    'titleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Adolescence', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 13,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvMiniSeries',
#     'text': 'TV Mini Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1814727170',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNGY1YjBiNzMtYWZhNC00OWViLWE0MzItNjc4YzczOGNiM2I0XkEyXkFqcGc@._V1_.jpg',
#     'height': 2222,
#     'width': 1500},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 2,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31510819',
#    'titleText': {'text': 'MobLand', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'MobLand', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 30,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3442052866',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNjQzZWVkMDQtZTgyZC00ZjVlLThlMTktNDBjNDU1Y2JhNDhkXkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2000},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 3,
#     'rankChange': {'changeDirection': 'UP', 'difference': 56}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt11280740',
#    'titleText': {'text': 'Severance', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Severance', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 2,
#     'day': 18,
#     'year': 2022,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1676647938',
#     'url': 'https://m.media-amazon.com/images/M/MV5BZDI5YzJhODQtMzQyNy00YWNmLWIxMjUtNDBjNjA5YWRjMzExXkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2000},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 4,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt18923754',
#    'titleText': {'text': 'Daredevil: Born Again', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Daredevil: Born Again',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 4,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1760660226',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMDRiNTBlY2EtZmRiZC00Mzc4LTljZDctNWQ5ZGY2NjUwNjE4XkEyXkFqcGc@._V1_.jpg',
#     'height': 1599,
#     'width': 1080},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 5,
#     'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt8740614',
#    'titleText': {'text': 'The Residence', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Residence', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 20,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvMiniSeries',
#     'text': 'TV Mini Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Mini Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2885784834',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNmJlOWFiNGEtZGYyMy00ZWY5LWJlMjMtYjgzZTViNDI3NzUxXkEyXkFqcGc@._V1_.jpg',
#     'height': 12000,
#     'width': 8100},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 6,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 2}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt18335752',
#    'titleText': {'text': '1923', 'isOriginalTitle': False},
#    'originalTitleText': {'text': '1923: A Yellowstone Origin Story',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': 2025},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 12,
#     'day': 18,
#     'year': 2022,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2131792898',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MGViZTItMmI5NS00MzMwLWFkNjctOGFlNWVmNDM0N2QyXkEyXkFqcGc@._V1_.jpg',
#     'height': 4000,
#     'width': 2700},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 7,
#     'rankChange': {'changeDirection': 'UP', 'difference': 3}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt31938062',
#    'titleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Pitt', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 1,
#     'day': 9,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2334957058',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMTU3MDliMGEtMDQxNi00OTk1LTg1NWMtZDM2NmEwZDA1ZDk2XkEyXkFqcGc@._V1_.jpg',
#     'height': 1200,
#     'width': 810},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 8,
#     'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt9288030',
#    'titleText': {'text': 'Reacher', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Reacher', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2022, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 2,
#     'day': 4,
#     'year': 2022,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1559797250',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMzdjYWZlMDQtYzdhNi00NmRlLTg2NzUtMTI3MWFhZDliNjBiXkEyXkFqcGc@._V1_.jpg',
#     'height': 1920,
#     'width': 1080},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 9,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 3}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt2172954',
#    'titleText': {'text': 'The Life List', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Life List', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 28,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2935720450',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMjNhNzUyMTQtYTFiZS00NzM2LWI3YTgtZmI1ZTA1MDUzMzBhXkEyXkFqcGc@._V1_.jpg',
#     'height': 2222,
#     'width': 1500},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 3,
#     'rankChange': {'changeDirection': 'UP', 'difference': 39}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt23649128',
#    'titleText': {'text': 'The Studio', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Studio', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 26,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm935172866',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMDQxMWI5OTMtNGRkMC00NTVlLWI5ZjAtZmFiMjMwM2M0N2E0XkEyXkFqcGc@._V1_.jpg',
#     'height': 755,
#     'width': 604},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 10,
#     'rankChange': {'changeDirection': 'UP', 'difference': 1}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt28256288',
#    'titleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Bondsman', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 4,
#     'day': 3,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1499500034',
#     'url': 'https://m.media-amazon.com/images/M/MV5BZjczOGY5MzEtYWJiNS00ZDQyLThhNzAtZTVhMTkxOWI3MjczXkEyXkFqcGc@._V1_.jpg',
#     'height': 1350,
#     'width': 1080},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 11,
#     'rankChange': {'changeDirection': 'UP', 'difference': 600}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt9150192',
#    'titleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'A Working Man', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 28,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm3791164162',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYmQxZGIxNTYtYTQwMy00ODdkLWI0MmQtM2E0ZmIyNmYzMGMzXkEyXkFqcGc@._V1_.jpg',
#     'height': 4096,
#     'width': 2764},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 4,
#     'rankChange': {'changeDirection': 'UP', 'difference': 9}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt30988739',
#    'titleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Black Bag', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 14,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'movie',
#     'text': 'Movie',
#     'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}],
#     'canHaveEpisodes': False,
#     'isEpisode': False,
#     'isSeries': False,
#     'displayableProperty': {'value': {'plainText': ''}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm2339149314',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNzA1OWU4NDMtMDUxMC00NWI4LWJhYjUtYWQ0OGQ5MTc2NDRjXkEyXkFqcGc@._V1_.jpg',
#     'height': 12000,
#     'width': 8100},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 5,
#     'rankChange': {'changeDirection': 'UP', 'difference': 2}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt7462410',
#    'titleText': {'text': 'The Wheel of Time', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'The Wheel of Time', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 11,
#     'day': 19,
#     'year': 2021,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm4100690946',
#     'url': 'https://m.media-amazon.com/images/M/MV5BNmQ5Y2U2MWYtZDcyMi00YTk5LWEyYjItNTI3ODg4MTdlMjYwXkEyXkFqcGc@._V1_.jpg',
#     'height': 1200,
#     'width': 960},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 12,
#     'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt6741278',
#    'titleText': {'text': 'Invincible', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Invincible', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 26,
#     'year': 2021,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1526242818',
#     'url': 'https://m.media-amazon.com/images/M/MV5BZjE4ZDU4ZjMtZjliYS00M2ZmLThkNTItN2U3MmJjOGU0NmIxXkEyXkFqcGc@._V1_.jpg',
#     'height': 3000,
#     'width': 2000},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 13,
#     'rankChange': {'changeDirection': 'DOWN', 'difference': 5}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt11041332',
#    'titleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Yellowjackets', 'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2021, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 11,
#     'day': 14,
#     'year': 2021,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm636520962',
#     'url': 'https://m.media-amazon.com/images/M/MV5BMDAwMDNiNDAtZjM0Yi00OTEyLWFkMGUtMzIxOGU0NWYzYmM4XkEyXkFqcGc@._V1_.jpg',
#     'height': 4000,
#     'width': 2700},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 14,
#     'rankChange': {'changeDirection': 'FLAT', 'difference': 0}}}},
#  {'node': {'__typename': 'Title',
#    'id': 'tt32641461',
#    'titleText': {'text': 'Mid-Century Modern', 'isOriginalTitle': True},
#    'originalTitleText': {'text': 'Mid-Century Modern',
#     'isOriginalTitle': True},
#    'releaseYear': {'__typename': 'YearRange', 'year': 2025, 'endYear': None},
#    'releaseDate': {'__typename': 'ReleaseDate',
#     'month': 3,
#     'day': 28,
#     'year': 2025,
#     'country': {'id': 'US'},
#     'restriction': None,
#     'attributes': [{'id': 'internet', 'text': 'internet'}],
#     'displayableProperty': {'qualifiersInMarkdownList': None}},
#    'titleType': {'__typename': 'TitleType',
#     'id': 'tvSeries',
#     'text': 'TV Series',
#     'categories': [{'id': 'tv', 'text': 'TV', 'value': 'tv'}],
#     'canHaveEpisodes': True,
#     'isEpisode': False,
#     'isSeries': True,
#     'displayableProperty': {'value': {'plainText': 'TV Series'}}},
#    'primaryImage': {'__typename': 'Image',
#     'id': 'rm1986103298',
#     'url': 'https://m.media-amazon.com/images/M/MV5BYmQ2MDE4M2YtNTBiYi00YWYzLTk3YWMtOTk1NWZkYWQwZWExXkEyXkFqcGc@._V1_.jpg',
#     'height': 12000,
#     'width': 8100},
#    'meterRanking': {'__typename': 'TitleMeterRanking',
#     'currentRank': 15,
#     'rankChange': {'changeDirection': 'UP', 'difference': 16}}}}]

# %%
type(data.get("data").get("topMeterTitles").get("edges"))
# Out:
# list

# %%
movie_1 = data.get("data").get("topMeterTitles").get("edges")[0]
nd = movie_1.get("node",{})
nd
title = nd.get("titleText",{}).get("text",{})
release_year = nd.get("releaseYear",{}).get("year",{})
rank = nd.get("meterRanking",{}).get("currentRank",{})
print(title,release_year,rank)
# Out:
# Snow White 2025 1

# %%
nodes = data.get("data").get("topMeterTitles").get("edges")
for node in nodes:
    nd = node.get("node",{})
    title = nd.get("titleText",{}).get("text",{})
    release_year = nd.get("releaseYear",{}).get("year",{})
    rank = nd.get("meterRanking",{}).get("currentRank",{})
    print(title,release_year,rank)
# Out:
# Snow White 2025 1
# The White Lotus 2021 1
# A Minecraft Movie 2025 2
# Adolescence 2025 2
# MobLand 2025 3
# Severance 2022 4
# Daredevil: Born Again 2025 5
# The Residence 2025 6
# 1923 2022 7
# The Pitt 2025 8
# Reacher 2022 9
# The Life List 2025 3
# The Studio 2025 10
# The Bondsman 2025 11
# A Working Man 2025 4
# Black Bag 2025 5
# The Wheel of Time 2021 12
# Invincible 2021 13
# Yellowjackets 2021 14
# Mid-Century Modern 2025 15

# %%
l1 = [2,3,4,5]
for i in l1:
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
nodes = data.get("data").get("topMeterTitles").get("edges")
top_movie_data = []
for node in nodes:
    nd = node.get("node",{})
    title = nd.get("titleText",{}).get("text",{})
    release_year = nd.get("releaseYear",{}).get("year",{})
    rank = nd.get("meterRanking",{}).get("currentRank",{})
    #print(title,release_year,rank)
    top_movie_data.append([title,release_year,rank])
print(top_movie_data)
# Out:
# [['Snow White', 2025, 1], ['The White Lotus', 2021, 1], ['A Minecraft Movie', 2025, 2], ['Adolescence', 2025, 2], ['MobLand', 2025, 3], ['Severance', 2022, 4], ['Daredevil: Born Again', 2025, 5], ['The Residence', 2025, 6], ['1923', 2022, 7], ['The Pitt', 2025, 8], ['Reacher', 2022, 9], ['The Life List', 2025, 3], ['The Studio', 2025, 10], ['The Bondsman', 2025, 11], ['A Working Man', 2025, 4], ['Black Bag', 2025, 5], ['The Wheel of Time', 2021, 12], ['Invincible', 2021, 13], ['Yellowjackets', 2021, 14], ['Mid-Century Modern', 2025, 15]]

# %%
l1 = [2,3,4,5]
l2 = []
l3 = []
for i in l1:
    l2.append(i)
    l2.append(i**2)
    l3.append([i,i**2])
print(l2)
print(l3)
# Out:
# [2, 4, 3, 9, 4, 16, 5, 25]
# [[2, 4], [3, 9], [4, 16], [5, 25]]

# %%
# to save the extracted/collected data to a csv file
import csv
with open("Top_movies.csv","w",encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Movie Titles","Release Year","Rank"])
    writer.writerows(top_movie_data)

# %%
import requests,csv

# %%
class api_extracter:

    def __init__(self,api_key):
        self.api_key = api_key

    def get_data(self):
        url = "https://imdb232.p.rapidapi.com/api/title/get-most-popular"

        querystring = {"limit":"20","topMeterTitlesType":"ALL"}

        headers = {
            "x-rapidapi-key": api_key,
            "x-rapidapi-host": "imdb232.p.rapidapi.com"
        }

        response = requests.get(url, headers=headers, params=querystring)

        #print(response.json())
        data = response.json()

        nodes = data.get("data").get("topMeterTitles").get("edges")
        top_movie_data = []
        for node in nodes:
            nd = node.get("node",{})
            title = nd.get("titleText",{}).get("text",{})
            release_year = nd.get("releaseYear",{}).get("year",{})
            rank = nd.get("meterRanking",{}).get("currentRank",{})
            #print(title,release_year,rank)
            top_movie_data.append([title,release_year,rank])
        return top_movie_data

    def save_files_csv(self,data):
        with open("Top_movies_2.csv","w",encoding="utf-8") as file:
            writer = csv.writer(file)
            writer.writerow(["Movie Titles","Release Year","Rank"])
            writer.writerows(data)
        print("File is saved succesfully")

# %%
api1 = api_extracter(api_key)
d1 = api1.get_data()
d1
# Out:
# [['Snow White', 2025, 1],
#  ['The White Lotus', 2021, 1],
#  ['A Minecraft Movie', 2025, 2],
#  ['Adolescence', 2025, 2],
#  ['MobLand', 2025, 3],
#  ['Severance', 2022, 4],
#  ['Daredevil: Born Again', 2025, 5],
#  ['The Residence', 2025, 6],
#  ['1923', 2022, 7],
#  ['The Pitt', 2025, 8],
#  ['Reacher', 2022, 9],
#  ['The Life List', 2025, 3],
#  ['The Studio', 2025, 10],
#  ['The Bondsman', 2025, 11],
#  ['A Working Man', 2025, 4],
#  ['Black Bag', 2025, 5],
#  ['The Wheel of Time', 2021, 12],
#  ['Invincible', 2021, 13],
#  ['Yellowjackets', 2021, 14],
#  ['Mid-Century Modern', 2025, 15]]

# %%
api1.save_files_csv(d1)
# Out:
# File is saved succesfully
